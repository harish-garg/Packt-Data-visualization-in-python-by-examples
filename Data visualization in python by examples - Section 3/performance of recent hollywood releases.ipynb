# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:450px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:450px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Import required modules

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize']=(12,7)

# %% [markdown]
# ### Read in and view data

# %%
df = pd.read_csv('data-movies.csv', index_col="Rank")
df.head()
# Out:
#                             Title Studio  Worldwide  Domestic  Overseas
# Rank
# 1     Beauty and the Beast (2017)     BV     1263.5     504.0     759.5
# 2         The Fate of the Furious   Uni.     1235.8     225.8    1010.0
# 3                 Despicable Me 3   Uni.     1032.0     264.2     767.8
# 4          Spider-Man: Homecoming   Sony      880.1     334.2     546.0
# 5                  Wolf Warrior 2     HC      870.3       2.7     867.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1 to 100
# Data columns (total 5 columns):
# Title        100 non-null object
# Studio       100 non-null object
# Worldwide    100 non-null float64
# Domestic     100 non-null float64
# Overseas     100 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 4.7+ KB

# %% [markdown]
# ### Visualizations

# %%
sns.barplot(y="Title", x="Worldwide", data=df);

# %%
sns.barplot(y="Title", x="Worldwide", data=df[:10]);

# %%
top10_domestic = df.sort_values(by='Domestic', ascending=False)[:10]
top10_domestic
# Out:
#                                Title   Studio  Worldwide  Domestic  Overseas
# Rank
# 1        Beauty and the Beast (2017)       BV     1263.5     504.0     759.5
# 7                       Wonder Woman       WB      821.8     412.6     409.2
# 6     Guardians of the Galaxy Vol. 2       BV      863.6     389.8     473.8
# 4             Spider-Man: Homecoming     Sony      880.1     334.2     546.0
# 10                                It  WB (NL)      688.0     326.9     361.1
# 3                    Despicable Me 3     Uni.     1032.0     264.2     767.8
# 9                     Thor: Ragnarok       BV      739.2     247.3     491.9
# 11                             Logan      Fox      616.8     226.3     390.5
# 2            The Fate of the Furious     Uni.     1235.8     225.8    1010.0
# 14                           Dunkirk       WB      525.0     188.0     337.0

# %%
sns.barplot(y="Title", x="Domestic", 
            data=top10_domestic);
sns.despine(left=True)

# %% [markdown]
# ### Using Grids

# %%
g = sns.PairGrid(df, vars=["Worldwide", "Domestic", "Overseas"], hue="Studio")
g.map(plt.scatter);
g.add_legend();

# %% [markdown]
# # More seaborn custimizations

# %% [markdown]
# ## Viewing seaborn palettes

# %%
sns.palplot(sns.color_palette("deep", 7))

# %%
sns.palplot(sns.color_palette("muted", 7))

# %%
sns.palplot(sns.color_palette("pastel", 7))

# %%
sns.palplot(sns.color_palette("bright", 7))

# %%
sns.palplot(sns.color_palette("dark", 7))

# %%
sns.palplot(sns.color_palette("colorblind", 7))

# %%
sns.boxplot(data=df);

# %% [markdown]
# ## matplotlib colormaps as color palettes

# %%
sns.palplot(sns.color_palette("RdBu", 7))

# %%
sns.palplot(sns.color_palette("Blues_d", 7))

# %% [markdown]
# ### Let's set the palette to a matplotlib colormap

# %%
sns.set_palette("Blues_d")

# %% [markdown]
# ### Impact on the plot

# %%
sns.boxplot(data=df);

# %% [markdown]
# ## Building custom color palettes

# %%
my_palette = ['#4B0082', '#0000FF', '#00FF00', '#FFFF00', '#FF7F00', '#FF0000']
sns.set_palette(my_palette)
sns.palplot(sns.color_palette())

# %%
sns.boxplot(data=df);

# %% [markdown]
# ## Plotting Context Presets

# %%
sns.set()
sns.set_context("paper")

# %%
sns.boxplot(data=df);

# %%
sns.set()
sns.set_context("poster")
sns.boxplot(data=df);
